# %% [markdown]
# <a href="https://colab.research.google.com/github/AnhVietPham/Deep-Learning/blob/main/GAN/SPADE_NVlabs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/NVlabs/SPADE.git && cd SPADE && pip install -r requirements.txt
# Out:
# fatal: destination path 'SPADE' already exists and is not an empty directory.

# %%
# !pip install dominate

# %%
# !cd SPADE/models/networks/ && git clone https://github.com/vacancy/Synchronized-BatchNorm-PyTorch && cp -rf Synchronized-BatchNorm-PyTorch/sync_batchnorm .
# Out:
# fatal: destination path 'Synchronized-BatchNorm-PyTorch' already exists and is not an empty directory.

# %%
# !pip install gdown && mkdir checkpoints
# Out:
# ...
# mkdir: cannot create directory ‘checkpoints’: File exists

# %%
# !cd checkpoints && gdown "https://drive.google.com/u/0/uc?id=12gvlTbMvUcJewQlSEaZdeb2CdOB-b8kQ" && tar xvf checkpoints.tar.gz
# Out:
# Downloading...
# From: https://drive.google.com/u/0/uc?id=12gvlTbMvUcJewQlSEaZdeb2CdOB-b8kQ
# To: /content/checkpoints/checkpoints.tar.gz
# 1.07GB [00:05, 208MB/s]
# ./
# ./checkpoints.tar.gz
# ./coco_pretrained/
# ./coco_pretrained/latest_net_G.pth
# ./ade20k_pretrained/
# ./ade20k_pretrained/latest_net_G.pth
# ./cityscapes_pretrained/
# ./cityscapes_pretrained/latest_net_G.pth

# %%
# !python SPADE/test.py --name coco_pretrained --dataset_mode coco --dataroot SPADE/datasets/coco_stuff --gpu_ids -1
# Out:
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                 batchSize: 1
#       cache_filelist_read: True
#      cache_filelist_write: True
#           checkpoints_dir: ./checkpoints
#         coco_no_portraits: False
#    contain_dontcare_label: True
#                 crop_size: 256
#                  dataroot: SPADE/datasets/coco_stuff     	[default: ./datasets/cityscapes/]
#              dataset_mode: coco
#           display_winsize: 256
#                   gpu_ids: -1                            	[default: 0]
#                  how_many: inf
#                 init_type: xavier
#             init_variance: 0.02
#                   isTrain: False                         	[default: None]
#                  label_nc: 182
#        load_from_opt_file: False
#                 load_size: 256
#          max_dataset_size: 9223372036854775807
#                     model: pix2pix
#                  nThreads: 0
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

plt.figure(figsize=(20,20))

ax_semantic = plt.subplot(1,2,1)
img = mpimg.imread('/content/results/coco_pretrained/test_latest/images/input_label/000000000139.png')
ax_semantic.imshow(img)

ax_synthesized = plt.subplot(1,2,2)
img = mpimg.imread('/content/results/coco_pretrained/test_latest/images/synthesized_image/000000000139.png')
ax_synthesized.imshow(img)

plt.show()
