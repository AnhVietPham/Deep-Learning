# %% [markdown]
# <a href="https://colab.research.google.com/github/AnhVietPham/Deep-Learning/blob/main/DLTensorflow/computer-vision/Object_Detection_Bounding_Box.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install d2l==0.17.0

# %%
import tensorflow as tf
from d2l import tensorflow as d2l

# %%
d2l.set_figsize()
img = d2l.plt.imread('/content/dog-facts-cat-facts.jpeg')
d2l.plt.imshow(img);

# %%
dog_bbox, cat_bbox = [160.0, 140.0, 250.0, 290.0], [250.0, 120.0, 380.0, 300.0]

# %%
def bbox_to_rect(bbox, color):
    return d2l.plt.Rectangle(
        xy=(bbox[0], bbox[1]), width=bbox[2]-bbox[0], height=bbox[3]-bbox[1],
        fill=False, edgecolor=color, linewidth=2)

# %%
fig = d2l.plt.imshow(img)
fig.axes.add_patch(bbox_to_rect(dog_bbox, 'blue'))
fig.axes.add_patch(bbox_to_rect(cat_bbox, 'red'));
